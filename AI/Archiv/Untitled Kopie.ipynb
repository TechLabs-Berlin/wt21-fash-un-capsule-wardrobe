# %%
import pandas as pd
import json

# %%
#df = pd.read_json()
data = json.load(open("/Users/lukasbauerschmidt/Desktop/TechLab/7. Vinted data/out/1.json"))
data
#df = pd.DataFrame(data["result"])
# Out:
# {'items': [{'id': 1534123352,
#    'title': 'Cute Outfit Set',
#    'brand_id': 131824,
#    'size_id': 4,
#    'status_id': 2,
#    'disposal_conditions': 6,
#    'user_id': 77643561,
#    'owner_id': None,
#    'country_id': 14,
#    'catalog_id': 18,
#    'color1_id': 15,
#    'color2_id': None,
#    'package_size_id': 1,
#    'is_hidden': 0,
#    'is_reserved': 0,
#    'reserved_for_user_id': None,
#    'is_visible': 1,
#    'is_unisex': 0,
#    'is_closed': 0,
#    'is_admin_alerted': False,
#    'active_bid_count': 0,
#    'favourite_count': 0,
#    'view_count': 1,
#    'moderation_status': 0,
#    'last_push_up_at': '2022-01-06T10:22:40-07:00',
#    'description': 'worn once\nsizeS\nstretchy',
#    'package_size_standard': True,
#    'item_closing_action': None,
#    'related_catalog_ids': [],
#    'related_catalogs_enabled': False,
#    'size': '6 / S',
#    'brand': 'Nobrand',
#    'composition': '',
#    'extra_conditions': '',
#    'is_for_sell': True,
#    'is_for_swap': True,
#    'is_for_give_away': False,
#    'is_handicraft': False,
#    'is_draft': False,
#    'label': 'Nobrand',
#    'real_value_numeric': None,
#    'original_price_numeric': '25.0',
#    'currency': 'USD',
#    'price_numeric': '25.0',
#    'created_at_ts': '2021-12-31T21:34:25-07:00',
#    'updated_at_ts': '2022-01-06T10:22:40-07:00',
#    'user_updated_at_ts': '2022-01-06T10:22:40-07:00',
#    'photos': [{'id': 5778222427,
#      'image_no': 1,
#      'width': 600,
#      'height': 800,
#      'dominant_color': '#74713B',
#      'dominant_color_opaque': '#D5D4C4',
#      'url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/f800/1641011665.jpeg?s=fd7da50bd3f011e07002ebbb45991d3a7b0dd8a9',
#      'is_main': True,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/70x100/1641011665.jpeg?s=0b001b3f3675953f9477c5ff027d4bbec4726752',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/150x210/1641011665.jpeg?s=490ad3d32563dd2dd9ee9df134d3483e03c38611',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/310x430/1641011665.jpeg?s=7b26dc01d54640be360ef5d522e9f72e0bb678f8',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/f800/1641011665.jpeg?s=fd7da50bd3f011e07002ebbb45991d3a7b0dd8a9',
#        'width': 321,
#        'height': 428,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/f800/1641011665.jpeg?s=fd7da50bd3f011e07002ebbb45991d3a7b0dd8a9',
#        'width': 468,
#        'height': 624,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/f800/1641011665.jpeg?s=fd7da50bd3f011e07002ebbb45991d3a7b0dd8a9',
#        'width': 273,
#        'height': 364,
#        'original_size': True}],
#      'high_resolution': {'id': '01_0265f_u7V6nQduQa2d9FptMVjpx1Zr',
#       'timestamp': 1641011665,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/01_0265f_u7V6nQduQa2d9FptMVjpx1Zr/1641011665.jpeg?s=adffce57b550dd7b8097f3db44e1413db09c113e',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5778222437,
#      'image_no': 2,
#      'width': 600,
#      'height': 800,
#      'dominant_color': '#3D3F3A',
#      'dominant_color_opaque': '#C5C5C4',
#      'url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/f800/1641011665.jpeg?s=0a8912daa3f0ce4bde49994c86db3d541569ee45',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/70x100/1641011665.jpeg?s=0163cf30ba98ce0a67f3c6e9395e1d8d62695552',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/150x210/1641011665.jpeg?s=adf5030a67dad73484fe2ad9e70beac25c685eb2',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/310x430/1641011665.jpeg?s=79eadcb9e9c2872270bd1f1b6c57d01928be0af9',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/f800/1641011665.jpeg?s=0a8912daa3f0ce4bde49994c86db3d541569ee45',
#        'width': 321,
#        'height': 428,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/f800/1641011665.jpeg?s=0a8912daa3f0ce4bde49994c86db3d541569ee45',
#        'width': 468,
#        'height': 624,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/f800/1641011665.jpeg?s=0a8912daa3f0ce4bde49994c86db3d541569ee45',
#        'width': 273,
#        'height': 364,
#        'original_size': True}],
#      'high_resolution': {'id': '03_0185c_EEwAAhDrsQpMw6faVdgXeD6M',
#       'timestamp': 1641011665,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/03_0185c_EEwAAhDrsQpMw6faVdgXeD6M/1641011665.jpeg?s=38688ced9d6109942b91815f227ae46ff53d6169',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5778222441,
#      'image_no': 3,
#      'width': 600,
#      'height': 800,
#      'dominant_color': '#44443D',
#      'dominant_color_opaque': '#C7C7C5',
#      'url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/f800/1641011665.jpeg?s=7481407970484cccc33c057015be788e19f97f5b',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/70x100/1641011665.jpeg?s=4b77c1bfc84083dd900280a3bf09f70d7af72006',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/150x210/1641011665.jpeg?s=f1408311d33c4297eea5bb675b195fd2087a18ed',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/310x430/1641011665.jpeg?s=8fe63d495fc61f7b3f144891df4642c849fb0f5b',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/f800/1641011665.jpeg?s=7481407970484cccc33c057015be788e19f97f5b',
#        'width': 321,
#        'height': 428,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/f800/1641011665.jpeg?s=7481407970484cccc33c057015be788e19f97f5b',
#        'width': 468,
#        'height': 624,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/f800/1641011665.jpeg?s=7481407970484cccc33c057015be788e19f97f5b',
#        'width': 273,
#        'height': 364,
#        'original_size': True}],
#      'high_resolution': {'id': '02_017f7_vmEbuj8xkqCnYg7PV17wfZbb',
#       'timestamp': 1641011665,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/02_017f7_vmEbuj8xkqCnYg7PV17wfZbb/1641011665.jpeg?s=bd538cf52bd1c991b2d44c43553ef7cdf2384fe4',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5778222447,
#      'image_no': 4,
#      'width': 600,
#      'height': 800,
#      'dominant_color': '#5D5E39',
#      'dominant_color_opaque': '#CECFC4',
#      'url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/f800/1641011665.jpeg?s=783a0597426e5ef1f97047c394bf0c2efd55d56a',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/70x100/1641011665.jpeg?s=a03118fd256b248ea0af4d6e964fd2c9bc77ddfc',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/150x210/1641011665.jpeg?s=5b47ee06b9e950437560b186a19afb3f6c9a8f31',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/310x430/1641011665.jpeg?s=562944afefca424ce8bea9ce71fb6697ae324220',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/f800/1641011665.jpeg?s=783a0597426e5ef1f97047c394bf0c2efd55d56a',
#        'width': 321,
#        'height': 428,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/f800/1641011665.jpeg?s=783a0597426e5ef1f97047c394bf0c2efd55d56a',
#        'width': 468,
#        'height': 624,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/f800/1641011665.jpeg?s=783a0597426e5ef1f97047c394bf0c2efd55d56a',
#        'width': 273,
#        'height': 364,
#        'original_size': True}],
#      'high_resolution': {'id': '03_00bf9_kLUBkxJeyJXux3uhFurLXuRs',
#       'timestamp': 1641011665,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/03_00bf9_kLUBkxJeyJXux3uhFurLXuRs/1641011665.jpeg?s=c571353c49518031982f89c4e2b1e5d532c5646f',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5778222458,
#      'image_no': 5,
#      'width': 600,
#      'height': 800,
#      'dominant_color': '#94856A',
#      'dominant_color_opaque': '#DFDAD2',
#      'url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/f800/1641011665.jpeg?s=9d7274fa838976e923eee9ce11d34e0a27401767',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/70x100/1641011665.jpeg?s=2001319c6ca225ea21c83497dd43cfd7d4613446',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/150x210/1641011665.jpeg?s=e294e708a12acf42304bef046bd9940d04265a8e',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/310x430/1641011665.jpeg?s=c0cc9c36ff1985af040bfbc7ef476b854af7986a',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/f800/1641011665.jpeg?s=9d7274fa838976e923eee9ce11d34e0a27401767',
#        'width': 321,
#        'height': 428,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/f800/1641011665.jpeg?s=9d7274fa838976e923eee9ce11d34e0a27401767',
#        'width': 468,
#        'height': 624,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/f800/1641011665.jpeg?s=9d7274fa838976e923eee9ce11d34e0a27401767',
#        'width': 273,
#        'height': 364,
#        'original_size': True}],
#      'high_resolution': {'id': '03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr',
#       'timestamp': 1641011665,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/03_019b6_dzkVpt9yQWiPwuV4WPKRxmCr/1641011665.jpeg?s=0a00d0df9854598535e65a972629cb157b8f5e53',
#      'is_hidden': False,
#      'extra': {}}],
#    'push_up_interval': 604800,
#    'can_be_sold': True,
#    'can_feedback': False,
#    'path': '/women/clothes/other-clothing/1534123352-cute-outfit-set',
#    'possible_to_request_reservation': True,
#    'item_reservation_id': None,
#    'receiver_id': None,
#    'promoted_until': '2022-01-13T10:22:40-07:00',
#    'discount_price_numeric': None,
#    'reservation_requests_from_users': [],
#    'material_id': None,
#    'author': None,
#    'book_title': None,
#    'isbn': None,
#    'transaction_permitted': True,
#    'user': {'id': 77643561,
#     'anon_id': '6db04569-be50-433a-8e1e-42121e6e0909',
#     'login': 'beautybero',
#     'real_name': None,
#     'email': None,
#     'birthday': None,
#     'gender': 'F',
#     'item_count': 6,
#     'msg_template_count': 1,
#     'given_item_count': 0,
#     'taken_item_count': 0,
#     'favourite_topic_count': 0,
#     'forum_msg_count': 0,
#     'forum_topic_count': 0,
#     'followers_count': 0,
#     'following_count': 0,
#     'following_brands_count': 0,
#     'positive_feedback_count': 0,
#     'neutral_feedback_count': 0,
#     'negative_feedback_count': 0,
#     'meeting_transaction_count': 0,
#     'account_status': 0,
#     'email_bounces': None,
#     'feedback_reputation': 0.0,
#     'account_ban_date': None,
#     'is_account_ban_permanent': None,
#     'is_forum_ban_permanent': None,
#     'is_on_holiday': False,
#     'is_publish_photos_agreed': False,
#     'is_identity': False,
#     'expose_location': True,
#     'third_party_tracking': True,
#     'created_at': '2021-12-31T08:48:27-07:00',
#     'last_loged_on_ts': '2022-01-06T10:12:18-07:00',
#     'city_id': 223901,
#     'city': 'HIALEAH, FL',
#     'country_id': 14,
#     'country_code': 'US',
#     'country_iso_code': 'US',
#     'country_title_local': 'United States',
#     'country_title': 'United States',
#     'contacts_permission': None,
#     'contacts': None,
#     'photo': {'id': 76857870,
#      'width': 800,
#      'height': 686,
#      'temp_uuid': None,
#      'url': 'https://images1.vinted.net/t/03_0054d_KAAUBVxzJdoBmPpccx5tdNxU/f800/1640965709.jpeg?s=5149cc1c7d24705bdd76f9648afa3ac6bfb56683',
#      'dominant_color': '#31abc2',
#      'dominant_color_opaque': '#C1E6ED',
#      'thumbnails': [{'type': 'thumb310',
#        'url': 'https://images1.vinted.net/t/03_0054d_KAAUBVxzJdoBmPpccx5tdNxU/310x310/1640965709.jpeg?s=b4e76c79c94c3964ab51541c7f23e1923e32f8b4',
#        'width': 310,
#        'height': 310,
#        'original_size': None},
#       {'type': 'thumb150',
#        'url': 'https://images1.vinted.net/t/03_0054d_KAAUBVxzJdoBmPpccx5tdNxU/150x150/1640965709.jpeg?s=99f5268fb02c2f44872e1f53843c5d0ffffaf12c',
#        'width': 150,
#        'height': 150,
#        'original_size': None},
#       {'type': 'thumb100',
#        'url': 'https://images1.vinted.net/t/03_0054d_KAAUBVxzJdoBmPpccx5tdNxU/100x100/1640965709.jpeg?s=10335577f1e68411cc1b9bc3c81512a7541f7e38',
#        'width': 100,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb50',
#        'url': 'https://images1.vinted.net/t/03_0054d_KAAUBVxzJdoBmPpccx5tdNxU/50x50/1640965709.jpeg?s=31572b42dbb759b3d5368c47ffbead7ca87f4a94',
#        'width': 50,
#        'height': 50,
#        'original_size': None},
#       {'type': 'thumb20',
#        'url': 'https://images1.vinted.net/t/03_0054d_KAAUBVxzJdoBmPpccx5tdNxU/20x20/1640965709.jpeg?s=d48a1e398ffdb57120bd1e810a4118d1e4d5c31b',
#        'width': 20,
#        'height': 20,
#        'original_size': None}],
#      'is_suspicious': False,
#      'orientation': None,
#      'high_resolution': {'id': '03_0054d_KAAUBVxzJdoBmPpccx5tdNxU',
#       'timestamp': 1640965709,
#       'orientation': None},
#      'full_size_url': 'https://images1.vinted.net/t/03_0054d_KAAUBVxzJdoBmPpccx5tdNxU/1640965709.jpeg?s=214b8efb73db52b5f9c91612a956651668605fbc',
#      'is_hidden': False,
#      'extra': {}},
#     'path': '/member/77643561-beautybero',
#     'is_god': False,
#     'is_tester': False,
#     'moderator': False,
#     'volunteer_moderator': False,
#     'hide_feedback': False,
#     'can_post_big_forum_photos': False,
#     'allow_direct_messaging': True,
#     'bundle_discount': {'id': 13337093,
#      'user_id': 77643561,
#      'enabled': True,
#      'minimal_item_count': 2,
#      'fraction': '0.15',
#      'discounts': [{'minimal_item_count': 2, 'fraction': '0.15'},
#       {'minimal_item_count': 3, 'fraction': '0.2'},
#       {'minimal_item_count': 5, 'fraction': '0.3'}]},
#     'donation_configuration': None,
#     'business': False,
#     'business_account': None,
#     'total_items_count': 6,
#     'about': '',
#     'verification': {'email': {'valid': True, 'available': True},
#      'facebook': {'valid': True,
#       'verified_at': '2021-12-31T08:48:26-07:00',
#       'available': True},
#      'google': {'valid': False, 'verified_at': None, 'available': True},
#      'phone': {'valid': False, 'verified_at': None, 'available': True}},
#     'closet_promoted_until': None,
#     'avg_response_time': None,
#     'carrier_ids': [2, 9, 10],
#     'carriers_without_custom_ids': [2],
#     'locale': 'en-us-fr',
#     'updated_on': 1641437269,
#     'is_hated': False,
#     'hates_you': False,
#     'is_favourite': False,
#     'profile_url': 'https://www.vinted.com/member/77643561-beautybero',
#     'share_profile_url': 'https://www.vinted.com/member/77643561-beautybero',
#     'facebook_user_id': None,
#     'is_online': False,
#     'has_promoted_closet': False,
#     'can_view_profile': True,
#     'can_bundle': True,
#     'last_loged_on': 'today 10:12 AM',
#     'accepted_pay_in_methods': [{'id': 1,
#       'code': 'CREDIT_CARD',
#       'requires_credit_card': True,
#       'event_tracking_code': 'cc',
#       'icon': 'credit-card',
#       'enabled': True,
#       'translated_name': 'Bank card',
#       'note': 'Vinted never shares your payment information with the seller or stores these details without your permission.'},
#      {'id': 16,
#       'code': 'APPLE_PAY',
#       'requires_credit_card': False,
#       'event_tracking_code': 'apple_pay',
#       'icon': 'apple-pay',
#       'enabled': True,
#       'translated_name': 'Apple Pay',
#       'note': ''},
#      {'id': 17,
#       'code': 'GOOGLE_PAY',
#       'requires_credit_card': False,
#       'event_tracking_code': 'google_pay',
#       'icon': 'google-pay',
#       'enabled': True,
#       'translated_name': 'Google Pay',
#       'note': ''},
#      {'id': 4,
#       'code': 'SOFORT',
#       'requires_credit_card': False,
#       'event_tracking_code': 'sofort',
#       'icon': 'sofort',
#       'enabled': True,
#       'translated_name': 'Sofort',
#       'note': ''},
#      {'id': 10,
#       'code': 'MANGOPAY_PAYPAL',
#       'requires_credit_card': False,
#       'event_tracking_code': 'mangopay_paypal',
#       'icon': 'paypal',
#       'enabled': True,
#       'translated_name': 'PayPal',
#       'note': ''},
#      {'id': 9,
#       'code': 'IDEAL',
#       'requires_credit_card': False,
#       'event_tracking_code': 'ideal',
#       'icon': 'ideal',
#       'enabled': True,
#       'translated_name': 'iDeal',
#       'note': ''}],
#     'localization': 'manual',
#     'default_address': None},
#    'price': '$25.00',
#    'discount_price': '',
#    'real_value': '',
#    'can_edit': False,
#    'can_delete': False,
#    'can_request_reservation': False,
#    'can_cancel_reservation_request': False,
#    'can_reserve': False,
#    'can_transfer': False,
#    'instant_buy': True,
#    'can_close': False,
#    'can_buy': True,
#    'can_bundle': True,
#    'can_ask_seller': True,
#    'can_favourite': False,
#    'user_login': 'beautybero',
#    'city_id': 223901,
#    'city': 'HIALEAH, FL',
#    'country': 'United States',
#    'nearby': None,
#    'distance': None,
#    'promoted': True,
#    'is_mobile': False,
#    'bump_badge_visible': False,
#    'brand_dto': {'id': 131824,
#     'title': 'Nobrand',
#     'slug': 'nobrand',
#     'favourite_count': 1506,
#     'pretty_favourite_count': '1.5K',
#     'item_count': 472980,
#     'pretty_item_count': '473K',
#     'is_visible_in_listings': True,
#     'path': '/brand/nobrand',
#     'requires_authenticity_check': False,
#     'is_luxury': False,
#     'url': 'https://www.vinted.com/brand/nobrand',
#     'is_favourite': False,
#     'is_hated': False},
#    'url': 'https://www.vinted.com/women/clothes/other-clothing/1534123352-cute-outfit-set',
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Bank card',
#      'note': 'Vinted never shares your payment information with the seller or stores these details without your permission.'}],
#    'created_at': '31/12/2021 09:34 PM',
#    'color1': 'Multi',
#    'color2': None,
#    'material': None,
#    'status': 'Very good',
#    'is_favourite': False,
#    'secure_purchase': True,
#    'performance': None,
#    'stats_visible': True,
#    'can_push_up': False,
#    'badge': None,
#    'size_guide_faq_entry_id': 506,
#    'localization': 'manual',
#    'free_return_img': 'https://www.vinted.com/assets/images/free-return/free-return-truck@3x-45bafb657ba592ad2730adea2add49930282f4febd4215c7f1c03a61db4fc8a5.png'},
#   {'id': 1531355808,
#    'title': 'Zara Trafaluc ruffle jacket',
#    'brand_id': 137,
#    'size_id': 5,
#    'status_id': 2,
#    'disposal_conditions': 4,
#    'user_id': 77525429,
#    'owner_id': None,
#    'country_id': 14,
#    'catalog_id': 571,
#    'color1_id': 25,
#    'color2_id': None,
#    'package_size_id': 3,
#    'is_hidden': 0,
#    'is_reserved': 0,
#    'reserved_for_user_id': None,
#    'is_visible': 1,
#    'is_unisex': 0,
#    'is_closed': 0,
#    'is_admin_alerted': False,
#    'active_bid_count': 0,
#    'favourite_count': 2,
#    'view_count': 3,
#    'moderation_status': 0,
#    'last_push_up_at': '2022-01-04T10:14:19-07:00',
#    'description': 'Barely worn\nZara jacket\nMedium\n',
#    'package_size_standard': True,
#    'item_closing_action': None,
#    'related_catalog_ids': [],
#    'related_catalogs_enabled': False,
#    'size': '8 / M',
#    'brand': 'Zara Trafaluc',
#    'composition': '',
#    'extra_conditions': '',
#    'is_for_sell': True,
#    'is_for_swap': False,
#    'is_for_give_away': False,
#    'is_handicraft': False,
#    'is_draft': False,
#    'label': 'Zara Trafaluc',
#    'real_value_numeric': None,
#    'original_price_numeric': '20.0',
#    'currency': 'USD',
#    'price_numeric': '18.0',
#    'created_at_ts': '2021-12-29T17:40:04-07:00',
#    'updated_at_ts': '2022-01-06T10:20:02-07:00',
#    'user_updated_at_ts': '2022-01-06T10:20:02-07:00',
#    'photos': [{'id': 5766897874,
#      'image_no': 1,
#      'width': 800,
#      'height': 745,
#      'dominant_color': '#856D7E',
#      'dominant_color_opaque': '#DAD3D8',
#      'url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/f800/1640824804.jpeg?s=3e0caab585618a68fe3e06b4a324dc3a4eb442b4',
#      'is_main': True,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/70x100/1640824804.jpeg?s=3495d09944f0ca0a63560667f9efb5e03574faba',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/150x210/1640824804.jpeg?s=27e238d6f62995a6210e0bb207636166a5e1995c',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/310x430/1640824804.jpeg?s=3e14571b4cc03e407962cdd53227c5c08cc6b1df',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/f800/1640824804.jpeg?s=3e0caab585618a68fe3e06b4a324dc3a4eb442b4',
#        'width': 428,
#        'height': 398,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/f800/1640824804.jpeg?s=3e0caab585618a68fe3e06b4a324dc3a4eb442b4',
#        'width': 623,
#        'height': 581,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/f800/1640824804.jpeg?s=3e0caab585618a68fe3e06b4a324dc3a4eb442b4',
#        'width': 364,
#        'height': 339,
#        'original_size': True}],
#      'high_resolution': {'id': '02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw',
#       'timestamp': 1640824804,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/02_023a6_WZ15u8vLQWNgCQCfrB5xGeCw/1640824804.jpeg?s=4d250dcd09e46d75018a2d38ea6d24dc622fc707',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5766897868,
#      'image_no': 2,
#      'width': 800,
#      'height': 768,
#      'dominant_color': '#917786',
#      'dominant_color_opaque': '#DED6DB',
#      'url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/f800/1640824804.jpeg?s=3be33fe78d8cdfe83e8c03f891d14928792fcbdc',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/70x100/1640824804.jpeg?s=4e1fe5b50fc8119414fc27f654dc7e5f8926e7db',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/150x210/1640824804.jpeg?s=ddf9998282bd8906fe55b310084991b7f7b79378',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/310x430/1640824804.jpeg?s=96aa3f1024bdb976387ece229b0893653e5f2c2d',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/f800/1640824804.jpeg?s=3be33fe78d8cdfe83e8c03f891d14928792fcbdc',
#        'width': 428,
#        'height': 410,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/f800/1640824804.jpeg?s=3be33fe78d8cdfe83e8c03f891d14928792fcbdc',
#        'width': 623,
#        'height': 599,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/f800/1640824804.jpeg?s=3be33fe78d8cdfe83e8c03f891d14928792fcbdc',
#        'width': 364,
#        'height': 349,
#        'original_size': True}],
#      'high_resolution': {'id': '01_0069e_w653JNiTpQURU1nF4jaoMYfu',
#       'timestamp': 1640824804,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/01_0069e_w653JNiTpQURU1nF4jaoMYfu/1640824804.jpeg?s=7b5bf98c59240872e3c7e81aa68fa6c8b783be9f',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5766897878,
#      'image_no': 3,
#      'width': 800,
#      'height': 752,
#      'dominant_color': '#A08D98',
#      'dominant_color_opaque': '#E3DDE0',
#      'url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/f800/1640824804.jpeg?s=b8ada93b5209cd7261e6f3473cbc0043bd97a1d6',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/70x100/1640824804.jpeg?s=4f449440793a25073ef4004d19df3a99bbc612ea',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/150x210/1640824804.jpeg?s=43d240fda23cb04242b2e43f72ded9a3694a5a31',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/310x430/1640824804.jpeg?s=df5760e557f3d10294b82cfa9634e7153c8e4ad3',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/f800/1640824804.jpeg?s=b8ada93b5209cd7261e6f3473cbc0043bd97a1d6',
#        'width': 428,
#        'height': 402,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/f800/1640824804.jpeg?s=b8ada93b5209cd7261e6f3473cbc0043bd97a1d6',
#        'width': 623,
#        'height': 587,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/f800/1640824804.jpeg?s=b8ada93b5209cd7261e6f3473cbc0043bd97a1d6',
#        'width': 364,
#        'height': 342,
#        'original_size': True}],
#      'high_resolution': {'id': '03_00129_7wZ4RiJYgYRuinAx4t6zymuR',
#       'timestamp': 1640824804,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/03_00129_7wZ4RiJYgYRuinAx4t6zymuR/1640824804.jpeg?s=ce2ab02a2d94fdfa566f23a30e6e6c92d3e67a77',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5766897881,
#      'image_no': 4,
#      'width': 800,
#      'height': 725,
#      'dominant_color': '#85717A',
#      'dominant_color_opaque': '#DAD4D7',
#      'url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/f800/1640824804.jpeg?s=b6dbbdd2ad1d7f7642b5530ba91f69cd1031ac20',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/70x100/1640824804.jpeg?s=6d27b756c84b58987aa5c1bf80ae6e89d70091db',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/150x210/1640824804.jpeg?s=f2a111a7eb21af60feeed8fd018b39de16db13de',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/310x430/1640824804.jpeg?s=764947ed8519e8ad960eb67cd62c12ad0a68c455',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/f800/1640824804.jpeg?s=b6dbbdd2ad1d7f7642b5530ba91f69cd1031ac20',
#        'width': 428,
#        'height': 388,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/f800/1640824804.jpeg?s=b6dbbdd2ad1d7f7642b5530ba91f69cd1031ac20',
#        'width': 623,
#        'height': 566,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/f800/1640824804.jpeg?s=b6dbbdd2ad1d7f7642b5530ba91f69cd1031ac20',
#        'width': 364,
#        'height': 330,
#        'original_size': True}],
#      'high_resolution': {'id': '01_02241_RzufUaap1f5YUG4xG4U7xmJ6',
#       'timestamp': 1640824804,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/01_02241_RzufUaap1f5YUG4xG4U7xmJ6/1640824804.jpeg?s=f6bb86e617ebed6c484c3af74ce4a7a709492f35',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5766897886,
#      'image_no': 5,
#      'width': 800,
#      'height': 708,
#      'dominant_color': '#917C84',
#      'dominant_color_opaque': '#DED8DA',
#      'url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/f800/1640824804.jpeg?s=918ef73d9616dbf10c091d96b05b7af69252ae34',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/70x100/1640824804.jpeg?s=52b260f82b267bd12e8b905a9dcea90c0e82f15e',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/150x210/1640824804.jpeg?s=1f4409345348743fd21ba99dfb7792452833d0c8',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/310x430/1640824804.jpeg?s=ae91877bddab799f2b502f6abc44a0e033353ba5',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/f800/1640824804.jpeg?s=918ef73d9616dbf10c091d96b05b7af69252ae34',
#        'width': 428,
#        'height': 379,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/f800/1640824804.jpeg?s=918ef73d9616dbf10c091d96b05b7af69252ae34',
#        'width': 623,
#        'height': 552,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/f800/1640824804.jpeg?s=918ef73d9616dbf10c091d96b05b7af69252ae34',
#        'width': 364,
#        'height': 322,
#        'original_size': True}],
#      'high_resolution': {'id': '03_013f5_8tBjXdwWEhnwyXN759iWf9XK',
#       'timestamp': 1640824804,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/03_013f5_8tBjXdwWEhnwyXN759iWf9XK/1640824804.jpeg?s=b3ff09c0c23e02a10e7e217714f3166429116be0',
#      'is_hidden': False,
#      'extra': {}}],
#    'push_up_interval': 604800,
#    'can_be_sold': True,
#    'can_feedback': False,
#    'path': '/women/clothes/activewear/outerwear/1531355808-zara-trafaluc-ruffle-jacket',
#    'possible_to_request_reservation': True,
#    'item_reservation_id': None,
#    'receiver_id': None,
#    'promoted_until': '2022-01-11T10:14:19-07:00',
#    'discount_price_numeric': None,
#    'reservation_requests_from_users': [],
#    'material_id': None,
#    'author': None,
#    'book_title': None,
#    'isbn': None,
#    'transaction_permitted': True,
#    'user': {'id': 77525429,
#     'anon_id': '9025cae2-5431-4f97-b6b8-725cfb7548a1',
#     'login': 'thebird1129',
#     'real_name': None,
#     'email': None,
#     'birthday': None,
#     'gender': 'F',
#     'item_count': 5,
#     'msg_template_count': 0,
#     'given_item_count': 0,
#     'taken_item_count': 0,
#     'favourite_topic_count': 0,
#     'forum_msg_count': 0,
#     'forum_topic_count': 0,
#     'followers_count': 0,
#     'following_count': 0,
#     'following_brands_count': 0,
#     'positive_feedback_count': 0,
#     'neutral_feedback_count': 0,
#     'negative_feedback_count': 0,
#     'meeting_transaction_count': 0,
#     'account_status': 0,
#     'email_bounces': None,
#     'feedback_reputation': 0.0,
#     'account_ban_date': None,
#     'is_account_ban_permanent': None,
#     'is_forum_ban_permanent': None,
#     'is_on_holiday': False,
#     'is_publish_photos_agreed': False,
#     'is_identity': False,
#     'expose_location': True,
#     'third_party_tracking': True,
#     'default_address': None,
#     'created_at': '2021-12-29T13:47:43-07:00',
#     'last_loged_on_ts': '2022-01-04T10:13:56-07:00',
#     'city_id': 225782,
#     'city': 'MATTHEWS, NC',
#     'country_id': 14,
#     'country_code': 'US',
#     'country_iso_code': 'US',
#     'country_title_local': 'United States',
#     'country_title': 'United States',
#     'contacts_permission': None,
#     'contacts': None,
#     'photo': {'id': 76736544,
#      'width': 800,
#      'height': 600,
#      'temp_uuid': None,
#      'url': 'https://images1.vinted.net/t/03_019ab_VBVaHvjJtJawTUL86KfiAWkF/f800/1640810864.jpeg?s=3d2cb56873c214f8c722460e7cd426509868a767',
#      'dominant_color': '#31abc2',
#      'dominant_color_opaque': '#C1E6ED',
#      'thumbnails': [{'type': 'thumb310',
#        'url': 'https://images1.vinted.net/t/03_019ab_VBVaHvjJtJawTUL86KfiAWkF/310x310/1640810864.jpeg?s=bb11762ff128aa635eb4fff3287e77b8312ad881',
#        'width': 310,
#        'height': 310,
#        'original_size': None},
#       {'type': 'thumb150',
#        'url': 'https://images1.vinted.net/t/03_019ab_VBVaHvjJtJawTUL86KfiAWkF/150x150/1640810864.jpeg?s=1a73be57377f9c68560dfdb69fe8d589d145fed3',
#        'width': 150,
#        'height': 150,
#        'original_size': None},
#       {'type': 'thumb100',
#        'url': 'https://images1.vinted.net/t/03_019ab_VBVaHvjJtJawTUL86KfiAWkF/100x100/1640810864.jpeg?s=d64f781f1e19a36cb035965016712cc99a55710f',
#        'width': 100,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb50',
#        'url': 'https://images1.vinted.net/t/03_019ab_VBVaHvjJtJawTUL86KfiAWkF/50x50/1640810864.jpeg?s=2c30e40e3d3e03507cc6a033e364fc6d31d48de7',
#        'width': 50,
#        'height': 50,
#        'original_size': None},
#       {'type': 'thumb20',
#        'url': 'https://images1.vinted.net/t/03_019ab_VBVaHvjJtJawTUL86KfiAWkF/20x20/1640810864.jpeg?s=17ea2fa65d433c5956759a4d74290ea5498c5286',
#        'width': 20,
#        'height': 20,
#        'original_size': None}],
#      'is_suspicious': False,
#      'orientation': None,
#      'high_resolution': {'id': '03_019ab_VBVaHvjJtJawTUL86KfiAWkF',
#       'timestamp': 1640810864,
#       'orientation': None},
#      'full_size_url': 'https://images1.vinted.net/t/03_019ab_VBVaHvjJtJawTUL86KfiAWkF/1640810864.jpeg?s=cf73b44a2ca9e6d796e30428ed0e67d5e2bece07',
#      'is_hidden': False,
#      'extra': {}},
#     'path': '/member/77525429-thebird1129',
#     'is_god': False,
#     'is_tester': False,
#     'moderator': False,
#     'volunteer_moderator': False,
#     'hide_feedback': False,
#     'can_post_big_forum_photos': False,
#     'allow_direct_messaging': True,
#     'bundle_discount': {'id': 13322316,
#      'user_id': 77525429,
#      'enabled': False,
#      'minimal_item_count': 2,
#      'fraction': '0.25',
#      'discounts': [{'minimal_item_count': 2, 'fraction': '0.25'},
#       {'minimal_item_count': 3, 'fraction': '0.25'},
#       {'minimal_item_count': 5, 'fraction': '0.5'}]},
#     'donation_configuration': None,
#     'business': False,
#     'business_account': None,
#     'total_items_count': 5,
#     'about': '',
#     'verification': {'email': {'valid': True, 'available': True},
#      'facebook': {'valid': False, 'verified_at': None, 'available': True},
#      'google': {'valid': True,
#       'verified_at': '2021-12-29T13:47:43-07:00',
#       'available': True},
#      'phone': {'valid': False, 'verified_at': None, 'available': True}},
#     'closet_promoted_until': None,
#     'avg_response_time': None,
#     'carrier_ids': [2, 9, 10],
#     'carriers_without_custom_ids': [2],
#     'locale': 'en-us-fr',
#     'updated_on': 1640826794,
#     'is_hated': False,
#     'hates_you': False,
#     'is_favourite': False,
#     'profile_url': 'https://www.vinted.com/member/77525429-thebird1129',
#     'share_profile_url': 'https://www.vinted.com/member/77525429-thebird1129',
#     'facebook_user_id': None,
#     'is_online': False,
#     'has_promoted_closet': False,
#     'can_view_profile': True,
#     'can_bundle': True,
#     'last_loged_on': '01/04 10:13 AM',
#     'accepted_pay_in_methods': [{'id': 1,
#       'code': 'CREDIT_CARD',
#       'requires_credit_card': True,
#       'event_tracking_code': 'cc',
#       'icon': 'credit-card',
#       'enabled': True,
#       'translated_name': 'Bank card',
#       'note': 'Vinted never shares your payment information with the seller or stores these details without your permission.'},
#      {'id': 16,
#       'code': 'APPLE_PAY',
#       'requires_credit_card': False,
#       'event_tracking_code': 'apple_pay',
#       'icon': 'apple-pay',
#       'enabled': True,
#       'translated_name': 'Apple Pay',
#       'note': ''},
#      {'id': 17,
#       'code': 'GOOGLE_PAY',
#       'requires_credit_card': False,
#       'event_tracking_code': 'google_pay',
#       'icon': 'google-pay',
#       'enabled': True,
#       'translated_name': 'Google Pay',
#       'note': ''},
#      {'id': 4,
#       'code': 'SOFORT',
#       'requires_credit_card': False,
#       'event_tracking_code': 'sofort',
#       'icon': 'sofort',
#       'enabled': True,
#       'translated_name': 'Sofort',
#       'note': ''},
#      {'id': 10,
#       'code': 'MANGOPAY_PAYPAL',
#       'requires_credit_card': False,
#       'event_tracking_code': 'mangopay_paypal',
#       'icon': 'paypal',
#       'enabled': True,
#       'translated_name': 'PayPal',
#       'note': ''},
#      {'id': 9,
#       'code': 'IDEAL',
#       'requires_credit_card': False,
#       'event_tracking_code': 'ideal',
#       'icon': 'ideal',
#       'enabled': True,
#       'translated_name': 'iDeal',
#       'note': ''}],
#     'localization': 'manual'},
#    'price': '$18.00',
#    'discount_price': '',
#    'real_value': '',
#    'can_edit': False,
#    'can_delete': False,
#    'can_request_reservation': False,
#    'can_cancel_reservation_request': False,
#    'can_reserve': False,
#    'can_transfer': False,
#    'instant_buy': True,
#    'can_close': False,
#    'can_buy': True,
#    'can_bundle': True,
#    'can_ask_seller': True,
#    'can_favourite': False,
#    'user_login': 'thebird1129',
#    'city_id': 225782,
#    'city': 'MATTHEWS, NC',
#    'country': 'United States',
#    'nearby': None,
#    'distance': None,
#    'promoted': True,
#    'is_mobile': False,
#    'bump_badge_visible': False,
#    'brand_dto': {'id': 137,
#     'title': 'Zara Trafaluc',
#     'slug': 'zara-trafaluc',
#     'favourite_count': 4497,
#     'pretty_favourite_count': '4.5K',
#     'item_count': 80740,
#     'pretty_item_count': '80.7K',
#     'is_visible_in_listings': True,
#     'path': '/brand/zara-trafaluc',
#     'requires_authenticity_check': False,
#     'is_luxury': False,
#     'url': 'https://www.vinted.com/brand/zara-trafaluc',
#     'is_favourite': False,
#     'is_hated': False},
#    'url': 'https://www.vinted.com/women/clothes/activewear/outerwear/1531355808-zara-trafaluc-ruffle-jacket',
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Bank card',
#      'note': 'Vinted never shares your payment information with the seller or stores these details without your permission.'}],
#    'created_at': '29/12/2021 05:40 PM',
#    'color1': 'Lilac',
#    'color2': None,
#    'material': None,
#    'status': 'Very good',
#    'is_favourite': False,
#    'secure_purchase': True,
#    'performance': None,
#    'stats_visible': True,
#    'can_push_up': False,
#    'badge': None,
#    'size_guide_faq_entry_id': 506,
#    'localization': 'manual',
#    'free_return_img': 'https://www.vinted.com/assets/images/free-return/free-return-truck@3x-45bafb657ba592ad2730adea2add49930282f4febd4215c7f1c03a61db4fc8a5.png'},
#   {'id': 1528703766,
#    'title': 'Nintendo Switch Lite with charger - turquoise/teal with Sticker cover',
#    'brand_id': 77600,
#    'size_id': None,
#    'status_id': 2,
#    'disposal_conditions': 4,
#    'user_id': 77424757,
#    'owner_id': None,
#    'country_id': 14,
#    'catalog_id': 99,
#    'color1_id': 17,
#    'color2_id': None,
#    'package_size_id': 2,
#    'is_hidden': 0,
#    'is_reserved': 0,
#    'reserved_for_user_id': None,
#    'is_visible': 1,
#    'is_unisex': 0,
#    'is_closed': 0,
#    'is_admin_alerted': False,
#    'active_bid_count': 0,
#    'favourite_count': 0,
#    'view_count': 9,
#    'moderation_status': 0,
#    'last_push_up_at': '2022-01-05T10:13:46-07:00',
#    'description': '\nNintendo switch lite lightly used. I bought this in the beginning of the pandemic to play animal crossing and recently bought a switch console to play games on the tv. I’m interested in selling this switch to someone who it will make just as happy as it made me! This would come with the sticker cover shown in the photo or you are able to remove it if that’s preferred. This listing also includes the charger and does not include shipping. \n\n',
#    'package_size_standard': True,
#    'item_closing_action': None,
#    'related_catalog_ids': [],
#    'related_catalogs_enabled': False,
#    'size': '',
#    'brand': 'Nintendo',
#    'composition': '',
#    'extra_conditions': '',
#    'is_for_sell': True,
#    'is_for_swap': False,
#    'is_for_give_away': False,
#    'is_handicraft': False,
#    'is_draft': False,
#    'label': 'Nintendo',
#    'real_value_numeric': None,
#    'original_price_numeric': '180.0',
#    'currency': 'USD',
#    'price_numeric': '180.0',
#    'created_at_ts': '2021-12-28T09:33:20-07:00',
#    'updated_at_ts': '2022-01-06T10:20:02-07:00',
#    'user_updated_at_ts': '2022-01-06T10:20:02-07:00',
#    'photos': [{'id': 5756128019,
#      'image_no': 1,
#      'width': 600,
#      'height': 800,
#      'dominant_color': '#B2A8A9',
#      'dominant_color_opaque': '#E8E5E5',
#      'url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/f800/1640709924.jpeg?s=e176ead6d5259836c318d5beb3408b8d488bfca4',
#      'is_main': True,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/70x100/1640709924.jpeg?s=e2b79eb40321975f93cd15e1ab303c2a8628c8fb',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/150x210/1640709924.jpeg?s=d60a48dbb6a1d38837576d486981045ac3c1d7cd',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/310x430/1640709924.jpeg?s=dd67d61ba97d08f6edb596888837870dfc22ae6e',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/f800/1640709924.jpeg?s=e176ead6d5259836c318d5beb3408b8d488bfca4',
#        'width': 321,
#        'height': 428,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/f800/1640709924.jpeg?s=e176ead6d5259836c318d5beb3408b8d488bfca4',
#        'width': 468,
#        'height': 624,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/f800/1640709924.jpeg?s=e176ead6d5259836c318d5beb3408b8d488bfca4',
#        'width': 273,
#        'height': 364,
#        'original_size': True}],
#      'high_resolution': {'id': '02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH',
#       'timestamp': 1640709924,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/02_01eec_xQ2pnxKFQ3zDNsLDvgXzUVJH/1640709924.jpeg?s=b04829d5942f211aa36574a9cb9949f0aa15fbf1',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5756141681,
#      'image_no': 2,
#      'width': 600,
#      'height': 800,
#      'dominant_color': '#8E8986',
#      'dominant_color_opaque': '#DDDCDB',
#      'url': 'https://images1.vinted.net/t/01_022c1_h5q5z4JTfbAzNEh2fCP5yg65/f800/1640710073.jpeg?s=a8a42f393c620df9a8e67f5427bd5bf158a3fa13',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/01_022c1_h5q5z4JTfbAzNEh2fCP5yg65/70x100/1640710073.jpeg?s=d789a413f9278075da891588054b8ae8f14c5b6f',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/01_022c1_h5q5z4JTfbAzNEh2fCP5yg65/150x210/1640710073.jpeg?s=4d8f9a73b7de7928b89cf3d5bfe517dde7d47d48',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/01_022c1_h5q5z4JTfbAzNEh2fCP5yg65/310x430/1640710073.jpeg?s=bde105b6af86c534a53c1628d0a03bc8ee7b1141',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/01_022c1_h5q5z4JTfbAzNEh2fCP5yg65/f800/1640710073.jpeg?s=a8a42f393c620df9a8e67f5427bd5bf158a3fa13',
#        'width': 321,
#        'height': 428,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/01_022c1_h5q5z4JTfbAzNEh2fCP5yg65/f800/1640710073.jpeg?s=a8a42f393c620df9a8e67f5427bd5bf158a3fa13',
#        'width': 468,
#        'height': 624,
#        'original_size': True},
#       {'type': 'thumb364x428',
# ...
#    'currency': 'USD',
#    'price_numeric': '30.0',
#    'created_at_ts': '2021-12-25T15:53:47-07:00',
#    'updated_at_ts': '2022-01-06T10:20:01-07:00',
#    'user_updated_at_ts': '2022-01-06T10:20:01-07:00',
#    'photos': [{'id': 5737416155,
#      'image_no': 1,
#      'width': 800,
#      'height': 600,
#      'dominant_color': '#5B5C61',
#      'dominant_color_opaque': '#CECED0',
#      'url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/f800/1640472827.jpeg?s=c88bd32e444fa9241676039fbd7d7af6c9221a40',
#      'is_main': True,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/70x100/1640472827.jpeg?s=5270f4afd18110979a35df3e9ff19dd81e90c67b',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/150x210/1640472827.jpeg?s=10a084b560f2165c485e8edb756b92aa1f1aff82',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/310x430/1640472827.jpeg?s=9ac26ff0d392c39797037da0fcb0ebe1c83b9980',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/f800/1640472827.jpeg?s=c88bd32e444fa9241676039fbd7d7af6c9221a40',
#        'width': 428,
#        'height': 321,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/f800/1640472827.jpeg?s=c88bd32e444fa9241676039fbd7d7af6c9221a40',
#        'width': 624,
#        'height': 468,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/f800/1640472827.jpeg?s=c88bd32e444fa9241676039fbd7d7af6c9221a40',
#        'width': 364,
#        'height': 273,
#        'original_size': True}],
#      'high_resolution': {'id': '03_017de_1cExYF9Sk616HpU9uABbKBN9',
#       'timestamp': 1640472827,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/03_017de_1cExYF9Sk616HpU9uABbKBN9/1640472827.jpeg?s=9f733706bbbc7859c86481bfc8b767aeaa72b3a4',
#      'is_hidden': False,
#      'extra': {}},
#     {'id': 5737416282,
#      'image_no': 2,
#      'width': 800,
#      'height': 600,
#      'dominant_color': '#999487',
#      'dominant_color_opaque': '#E0DFDB',
#      'url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/f800/1640472827.jpeg?s=2555ccfd7ad98f224eade07ef5ecd17313ab105c',
#      'is_main': False,
#      'thumbnails': [{'type': 'thumb70x100',
#        'url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/70x100/1640472827.jpeg?s=510f1b19f6a8a4c0e747fd605763da8757ce0423',
#        'width': 70,
#        'height': 100,
#        'original_size': None},
#       {'type': 'thumb150x210',
#        'url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/150x210/1640472827.jpeg?s=31201c5ce3189a4e1937678a959d153c48f3fddb',
#        'width': 150,
#        'height': 210,
#        'original_size': None},
#       {'type': 'thumb310x430',
#        'url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/310x430/1640472827.jpeg?s=ce7c666f338d5e8cd826efeb658cab9782bea57b',
#        'width': 310,
#        'height': 430,
#        'original_size': None},
#       {'type': 'thumb428x624',
#        'url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/f800/1640472827.jpeg?s=2555ccfd7ad98f224eade07ef5ecd17313ab105c',
#        'width': 428,
#        'height': 321,
#        'original_size': True},
#       {'type': 'thumb624x428',
#        'url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/f800/1640472827.jpeg?s=2555ccfd7ad98f224eade07ef5ecd17313ab105c',
#        'width': 624,
#        'height': 468,
#        'original_size': True},
#       {'type': 'thumb364x428',
#        'url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/f800/1640472827.jpeg?s=2555ccfd7ad98f224eade07ef5ecd17313ab105c',
#        'width': 364,
#        'height': 273,
#        'original_size': True}],
#      'high_resolution': {'id': '03_003e2_iM1H12xSfE8sTU5oyLGU2KR2',
#       'timestamp': 1640472827,
#       'orientation': None},
#      'is_suspicious': False,
#      'full_size_url': 'https://images1.vinted.net/t/03_003e2_iM1H12xSfE8sTU5oyLGU2KR2/1640472827.jpeg?s=e657cd887593fc5b3da97f493521540f4999aba5',
#      'is_hidden': False,
#      'extra': {}}],
#    'push_up_interval': 604800,
#    'can_be_sold': True,
#    'can_feedback': False,
#    'path': '/kids/boys-clothing/coats-and-jackets/jackets/1524227564-the-north-face-kids-down-jacket',
#    'possible_to_request_reservation': True,
#    'item_reservation_id': None,
#    'receiver_id': None,
#    'promoted_until': '2022-01-07T10:11:22-07:00',
#    'discount_price_numeric': None,
#    'reservation_requests_from_users': [],
#    'material_id': None,
#    'author': None,
#    'book_title': None,
#    'isbn': None,
#    'transaction_permitted': True,
#    'user': {'id': 77213808,
#     'anon_id': '6398ad8d-ead2-4115-ac7e-5c329b194e0f',
#     'login': 'anzi78',
#     'real_name': None,
#     'email': None,
#     'birthday': None,
#     'gender': '',
#     'item_count': 2,
#     'msg_template_count': 0,
#     'given_item_count': 1,
#     'taken_item_count': 0,
#     'favourite_topic_count': 0,
#     'forum_msg_count': 0,
#     'forum_topic_count': 0,
#     'followers_count': 1,
#     'following_count': 0,
#     'following_brands_count': 0,
#     'positive_feedback_count': 0,
#     'neutral_feedback_count': 0,
#     'negative_feedback_count': 0,
#     'meeting_transaction_count': 0,
#     'account_status': 0,
#     'email_bounces': None,
#     'feedback_reputation': 0.0,
#     'account_ban_date': None,
#     'is_account_ban_permanent': None,
#     'is_forum_ban_permanent': None,
#     'is_on_holiday': False,
#     'is_publish_photos_agreed': False,
#     'is_identity': False,
#     'expose_location': True,
#     'third_party_tracking': True,
#     'default_address': None,
#     'created_at': '2021-12-25T11:46:09-07:00',
#     'last_loged_on_ts': '2022-01-04T12:08:37-07:00',
#     'city_id': 225296,
#     'city': 'SCOTTSDALE, AZ',
#     'country_id': 14,
#     'country_code': 'US',
#     'country_iso_code': 'US',
#     'country_title_local': 'United States',
#     'country_title': 'United States',
#     'contacts_permission': None,
#     'contacts': None,
#     'photo': None,
#     'path': '/member/77213808-anzi78',
#     'is_god': False,
#     'is_tester': False,
#     'moderator': False,
#     'volunteer_moderator': False,
#     'hide_feedback': False,
#     'can_post_big_forum_photos': False,
#     'allow_direct_messaging': True,
#     'bundle_discount': None,
#     'donation_configuration': None,
#     'business': False,
#     'business_account': None,
#     'total_items_count': 3,
#     'about': '',
#     'verification': {'email': {'valid': True, 'available': True},
#      'facebook': {'valid': False, 'verified_at': None, 'available': True},
#      'google': {'valid': False, 'verified_at': None, 'available': True},
#      'phone': {'valid': False, 'verified_at': None, 'available': True}},
#     'closet_promoted_until': None,
#     'avg_response_time': None,
#     'carrier_ids': [2, 9, 10],
#     'carriers_without_custom_ids': [2],
#     'locale': 'en-us-fr',
#     'updated_on': 1641366098,
#     'is_hated': False,
#     'hates_you': False,
#     'is_favourite': False,
#     'profile_url': 'https://www.vinted.com/member/77213808-anzi78',
#     'share_profile_url': 'https://www.vinted.com/member/77213808-anzi78',
#     'facebook_user_id': None,
#     'is_online': False,
#     'has_promoted_closet': False,
#     'can_view_profile': True,
#     'can_bundle': True,
#     'last_loged_on': '01/04 12:08 PM',
#     'accepted_pay_in_methods': [{'id': 1,
#       'code': 'CREDIT_CARD',
#       'requires_credit_card': True,
#       'event_tracking_code': 'cc',
#       'icon': 'credit-card',
#       'enabled': True,
#       'translated_name': 'Bank card',
#       'note': 'Vinted never shares your payment information with the seller or stores these details without your permission.'},
#      {'id': 16,
#       'code': 'APPLE_PAY',
#       'requires_credit_card': False,
#       'event_tracking_code': 'apple_pay',
#       'icon': 'apple-pay',
#       'enabled': True,
#       'translated_name': 'Apple Pay',
#       'note': ''},
#      {'id': 17,
#       'code': 'GOOGLE_PAY',
#       'requires_credit_card': False,
#       'event_tracking_code': 'google_pay',
#       'icon': 'google-pay',
#       'enabled': True,
#       'translated_name': 'Google Pay',
#       'note': ''},
#      {'id': 4,
#       'code': 'SOFORT',
#       'requires_credit_card': False,
#       'event_tracking_code': 'sofort',
#       'icon': 'sofort',
#       'enabled': True,
#       'translated_name': 'Sofort',
#       'note': ''},
#      {'id': 10,
#       'code': 'MANGOPAY_PAYPAL',
#       'requires_credit_card': False,
#       'event_tracking_code': 'mangopay_paypal',
#       'icon': 'paypal',
#       'enabled': True,
#       'translated_name': 'PayPal',
#       'note': ''},
#      {'id': 9,
#       'code': 'IDEAL',
#       'requires_credit_card': False,
#       'event_tracking_code': 'ideal',
#       'icon': 'ideal',
#       'enabled': True,
#       'translated_name': 'iDeal',
#       'note': ''}],
#     'localization': 'manual'},
#    'price': '$30.00',
#    'discount_price': '',
#    'real_value': '',
#    'can_edit': False,
#    'can_delete': False,
#    'can_request_reservation': False,
#    'can_cancel_reservation_request': False,
#    'can_reserve': False,
#    'can_transfer': False,
#    'instant_buy': True,
#    'can_close': False,
#    'can_buy': True,
#    'can_bundle': True,
#    'can_ask_seller': True,
#    'can_favourite': False,
#    'user_login': 'anzi78',
#    'city_id': 225296,
#    'city': 'SCOTTSDALE, AZ',
#    'country': 'United States',
#    'nearby': None,
#    'distance': None,
#    'promoted': True,
#    'is_mobile': False,
#    'bump_badge_visible': False,
#    'brand_dto': {'id': 2319,
#     'title': 'The North Face',
#     'slug': 'the-north-face',
#     'favourite_count': 208885,
#     'pretty_favourite_count': '208.9K',
#     'item_count': 425464,
#     'pretty_item_count': '425.5K',
#     'is_visible_in_listings': True,
#     'path': '/brand/the-north-face',
#     'requires_authenticity_check': True,
#     'is_luxury': True,
#     'url': 'https://www.vinted.com/brand/the-north-face',
#     'is_favourite': False,
#     'is_hated': False},
#    'url': 'https://www.vinted.com/kids/boys-clothing/coats-and-jackets/jackets/1524227564-the-north-face-kids-down-jacket',
#    'accepted_pay_in_methods': [{'id': 1,
#      'code': 'CREDIT_CARD',
#      'requires_credit_card': True,
#      'event_tracking_code': 'cc',
#      'icon': 'credit-card',
#      'enabled': True,
#      'translated_name': 'Bank card',
#      'note': 'Vinted never shares your payment information with the seller or stores these details without your permission.'}],
#    'created_at': '25/12/2021 03:53 PM',
#    'color1': 'Black',
#    'color2': None,
#    'material': None,
#    'status': 'Very good',
#    'is_favourite': False,
#    'secure_purchase': True,
#    'performance': None,
#    'stats_visible': True,
#    'can_push_up': False,
#    'badge': None,
#    'size_guide_faq_entry_id': 516,
#    'localization': 'manual',
#    'free_return_img': 'https://www.vinted.com/assets/images/free-return/free-return-truck@3x-45bafb657ba592ad2730adea2add49930282f4febd4215c7f1c03a61db4fc8a5.png'}],
#  'item_params_by_id': {'1534123352': {'buyer_item_distance_km': None,
#    'score': 6.799091,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1531355808': {'buyer_item_distance_km': None,
#    'score': 6.798764,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1528703766': {'buyer_item_distance_km': None,
#    'score': 6.798764,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1543497921': {'buyer_item_distance_km': None,
#    'score': 6.798764,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1540979897': {'buyer_item_distance_km': None,
#    'score': 6.798764,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1530277392': {'buyer_item_distance_km': None,
#    'score': 6.798764,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1508543857': {'buyer_item_distance_km': None,
#    'score': 6.798764,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1533142135': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1531348954': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1514451318': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1533134330': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1530588840': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1524033714': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1537408927': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1537936949': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1530936951': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1533141515': {'buyer_item_distance_km': None,
#    'score': 6.7987638,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1541420945': {'buyer_item_distance_km': None,
#    'score': 6.7987633,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1525728778': {'buyer_item_distance_km': None,
#    'score': 6.7987633,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1511852444': {'buyer_item_distance_km': None,
#    'score': 6.7987633,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1512485103': {'buyer_item_distance_km': None,
#    'score': 6.7987633,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1511826295': {'buyer_item_distance_km': None,
#    'score': 6.7987633,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1533137399': {'buyer_item_distance_km': None,
#    'score': 6.7987633,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']},
#   '1524227564': {'buyer_item_distance_km': None,
#    'score': 6.7987633,
#    'matched_queries': ['high_volume_seller_boost',
#     'boost_by_newest_items',
#     'promoted_items_boost']}},
#  'pagination': {'current_page': 1,
#   'total_pages': 125,
#   'total_entries': 3000,
#   'per_page': 24,
#   'time': 1641491168},
#  'search_correlation_id': '29eb051b-59a0-411b-8af8-c9d5a61eb640',
#  'search_session_id': 'e6b70e96-8f6c-4349-8eeb-f0d228a4e1d4',
#  'code': 0}
