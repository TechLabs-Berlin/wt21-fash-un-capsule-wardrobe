# %%
import os
from glob import glob
import urllib.request
import pandas as pd
import glob, os, json
import wget

dictio={}
counter=0
for f_name in glob.iglob("/Users/lukasbauerschmidt/Desktop/TechLab/3. Project/3. Code/wt21-fash-un-capsule-wardrobe/AI/out2/*.json"):
    for i,item in enumerate(json.load(open(f_name))["items"]):
        counter+=1
        dictio["{}.jpeg".format(counter)]=[{"image": json.load(open(f_name))["items"][i]["photo"][0]["full_size_url"], 
                          "website-url": "https://www.vinted.de{}".format(json.load(open(f_name))["items"][i]["path"]),
                          "price": json.load(open(f_name))["items"][i]["price"],
                          "user name": json.load(open(f_name))["items"][i]["user"]["login"],
                          "title": json.load(open(f_name))["items"][i]["title"]}]
        
        
dictio
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7182832e9f39> in <module>
#      11     for i,item in enumerate(json.load(open(f_name))["items"]):
#      12         counter+=1
# ---> 13         dictio["{}.jpeg".format(counter)]=[{"image": json.load(open(f_name))["items"][i]["photo"][0]["full_size_url"],
#      14                           "website-url": "https://www.vinted.de{}".format(json.load(open(f_name))["items"][i]["path"]),
#      15                           "price": json.load(open(f_name))["items"][i]["price"],
#
# KeyError: 0

# %%
json_1 = json.load(open("/Users/lukasbauerschmidt/Desktop/TechLab/3. Project/3. Code/wt21-fash-un-capsule-wardrobe/AI/out2/1.json"))
json_1["items"][0]
# Out:
# {'id': 1579202898,
#  'title': 'Lane Bryant plus size skirt size 22/24',
#  'price': '12.0',
#  'discount': None,
#  'currency': 'USD',
#  'brand_title': 'Lane Bryant',
#  'size_title': '22 / 3 X',
#  'is_for_swap': False,
#  'user': {'id': 73135059,
#   'login': 'baraginboutique22',
#   'profile_url': 'https://www.vinted.com/member/73135059-baraginboutique22',
#   'photo': {'id': 79646195,
#    'width': 437,
#    'height': 800,
#    'temp_uuid': None,
#    'url': 'https://images1.vinted.net/t/03_01422_QqP5LHwr4SdGRkdT5vMLTf44/f800/1643426190.jpeg?s=aec10cd5ab8191f87ca86c70595d66bb6ccb5417',
#    'dominant_color': '#31abc2',
#    'dominant_color_opaque': '#C1E6ED',
#    'thumbnails': [{'type': 'thumb310',
#      'url': 'https://images1.vinted.net/t/03_01422_QqP5LHwr4SdGRkdT5vMLTf44/310x310/1643426190.jpeg?s=4ef03d9a7f5fe7b93a48f370585cd798a18c11e0',
#      'width': 310,
#      'height': 310,
#      'original_size': None},
#     {'type': 'thumb150',
# ...

# %%
for i in list(dictio.keys()):
        
        wget.download(dictio[i][0]["image"], out="/Users/lukasbauerschmidt/Desktop/TechLab/3. Project/3. Code/wt21-fash-un-capsule-wardrobe/AI/databaseNew/{}.jpeg".format(i))
