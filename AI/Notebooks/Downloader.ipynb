# %%
import os
from glob import glob
import urllib.request
import pandas as pd
import glob, os, json
import wget

dictio={}
counter=0
for f_name in glob.iglob("/Users/lukasbauerschmidt/Desktop/TechLab/3. Project/3. Code/wt21-fash-un-capsule-wardrobe/AI/out4/*.json"):
    for i,item in enumerate(json.load(open(f_name))["items"]):
        counter+=1
        dictio["{}.jpeg".format(counter)]=[{"image": json.load(open(f_name))["items"][i]["photo"]["full_size_url"], 
                          "website-url": json.load(open(f_name))["items"][i]["url"],
                          "price": json.load(open(f_name))["items"][i]["price"],
                          "user name": json.load(open(f_name))["items"][i]["user"]["login"],
                          "title": json.load(open(f_name))["items"][i]["title"]}]
        
        
dictio
# Out:
# {'1.jpeg': [{'image': 'https://images1.vinted.net/t/03_01816_kCuuoYqpyxLJhB4EVtu2i9GB/1643590027.jpeg?s=b7e668527ec3e76763d334aa5b34e437e33a0a09',
#    'website-url': 'https://www.vinted.com/women/clothes/lingerie-and-nightwear/panties/1600502462-victoria-secret-panty',
#    'price': '3.0',
#    'user name': 'dezsshop',
#    'title': 'Victoria secret panty'}],
#  '2.jpeg': [{'image': 'https://images1.vinted.net/t/03_00984_DQm3o23VgeksjzzryiUY6a7w/1643602349.jpeg?s=cdabc5c599cd339fef59181904b9b4af57e86195',
#    'website-url': 'https://www.vinted.com/women/clothes/jumpers-and-sweaters/sweaters/knitted-sweaters/1600502450-american-apparel-navy-fisherman-sweater',
#    'price': '9.0',
#    'user name': 'kfmx',
#    'title': 'American Apparel Navy Fisherman Sweater'}],
#  '3.jpeg': [{'image': 'https://images1.vinted.net/t/03_01df3_o9VHJM2Z1n7VytM64NpxwLuh/1643590015.jpeg?s=29b5e5a9a989cecf69eef6f48cf98712f9851b01',
# ...

# %%
dictio["2928.jpeg"]
# Out:
# [{'image': 'https://images1.vinted.net/t/03_0051f_NYrXQMk4n3pEZP2ECzL7s4o8/1643612344.jpeg?s=a42363ade0c2f2896bd663b1c22770dbb46efa80',
#   'website-url': 'https://www.vinted.com/men/clothes/activewear/hoodies-and-sweatshirts/1600545647-brand-new-nike-camo-hoodie',
#   'price': '30.0',
#   'user name': 'babygurl33',
#   'title': 'Brand new Nike camo hoodie'}]

# %%
for i in list(dictio.keys()):
        
        wget.download(dictio[i][0]["image"], out="/Users/lukasbauerschmidt/Desktop/TechLab/3. Project/3. Code/wt21-fash-un-capsule-wardrobe/AI/databaseNew/{}".format(i))

# %%
#from os import listdir, rename
#PfadZuDateien = '/Users/lukasbauerschmidt/Desktop/TechLab/3. Project/3. Code/wt21-fash-un-capsule-wardrobe/AI/databaseNew/'
#meineDateien = listdir(PfadZuDateien)
#print(meineDateien)


#i = 0
#for datei in meineDateien:
#    i += 1
#    rename(PfadZuDateien + datei, PfadZuDateien + str(i) + '.jpeg')

# %%
json.dump(dictio, open("/Users/lukasbauerschmidt/Desktop/TechLab/3. Project/3. Code/wt21-fash-un-capsule-wardrobe/AI/databaseNew/dictio", "w"))
